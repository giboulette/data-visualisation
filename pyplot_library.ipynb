# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib
from random import random
#%matplotlib widget
P = plt.rcParams

# %%
x = [random() for i in range(100)]
y = [random() for i in range(100)]
x_backup = x.copy()
y_backup = y.copy()
plt.xcorr(x, y)
plt.show()

plt.acorr(x)
plt.show()

# %%
plt.angle_spectrum(x)
plt.show()

# %%
plt.arrow(1,1,2,2,head_width=0.1)
plt.show()

# %%
for xi,yi in zip(x,y):
    plt.scatter(xi,yi)
#plt.autumn()
#plt.bone()
#plt.cool()
#plt.copper()
#plt.flag()
#plt.gray()
#plt.hot()
#plt.hsv()
#plt.inferno()
#plt.jet()
#plt.magma()
#plt.nipy_spectral()
#plt.pink()
#plt.plasma()
#plt.prism()
#plt.spring()
#plt.summer()
#plt.viridis()
#plt.winter()
plt.show()

# %%
plt.plot(x,y)
plt.axes((1,0,1,1),polar=True)
plt.scatter(y,x)
plt.show()

# %%
plt.axhline(0.5,0.2,0.8,color="r")
plt.axhspan(0.3,0.7,0.1,0.9,zorder=0,color="g")
plt.axline((0.5,0.5), xy2=None, slope=1)
plt.show()

# %%
plt.axvline(x=0.5, ymin=0.1, ymax=0.9,color="r")
plt.axvspan(xmin=0, xmax=1, ymin=0, ymax=1,zorder=0,color="g")
plt.axline((0.5,0.5), xy2=(1,1), slope=None)
plt.show()

# %%
import numpy as np
x_ = np.linspace(-5, 5, 5)
X, Y = np.meshgrid(x_, x_)
U, V = 12 * X, 12 * Y
  
data = [(-1.5, .5, -6, -6),
        (1, -1, -46, 46),
        (-3, -1, 11, -11),
        (1, 1.5, 80, 80),
        (0.5, 0.25, 25, 15),
        (-1.5, -0.5, -5, 40)]
  
data = np.array(data, dtype=[('x', np.float32),
                             ('y', np.float32),
                             ('u', np.float32), 
                             ('v', np.float32)])
  
plt.barbs(X, Y, U, V)
plt.show()

# %%
plt.bar(x, height=y,width=0.01)
plt.show()
plt.barh(x, y, height=0.01, left=None,align='center')
plt.show()

# %%
plt.plot(x,y)
plt.show()
plt.box(False)
plt.plot(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
xrange = [(xi,yi/100) for xi,yi in zip(x,y)]

plt.broken_barh(xrange,(.5,1.5))
plt.show()

# %%
plt.plot(x,y)
plt.cla()  # close current axis
plt.show()

# %%
plt.plot(x,y)
plt.clf()  # clear figure
plt.show()

# %%
delta = 0.025
x1 = np.arange(-3.0, 3.0, delta)
y1 = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x1, y1)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2

fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
plt.show()
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, CS.levels, inline=True, fontsize=10)
plt.show()

# %%
dt = 0.01
t = np.arange(0, 30, dt)   
s1 = 1.5 * np.sin(2 * np.pi * 10 * t)
s2 = np.cos(np.pi * t)
plt.cohere(s1,s2)
plt.show()

# %%
plt.scatter(0,0)
plt.colorbar()

# %%
# %matplotlib widget
t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2 * np.pi * t)
fig, ax = plt.subplots()
ax.plot(t, s)


def on_move(event):
    # get the x and y pixel coords
    x, y = event.x, event.y
    if event.inaxes:
        ax = event.inaxes  # the axes instance
        print('data coords % f % f' % (event.xdata,
                                       event.ydata))  
def on_click(event):
    if event.button is MouseButton.LEFT:
        print('disconnecting callback')
        plt.disconnect(binding_id)

#binding_id = plt.connect('motion_notify_event',on_move)
#plt.connect('button_press_event', on_click)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline

# %%
plt.csd(s1,s2)
plt.show()

# %%
fig = plt.figure()
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)
plt.errorbar(x, y + 3, yerr=yerr, label='both limits (default)')
plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label='uplims=True')
plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
             label='uplims=True, lolims=True')
upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label='subsets of uplims and lolims')
plt.legend(loc='lower right')
plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)
# create random data
data1 = np.random.random([6, 50])
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(6)]
# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [-15, -3, 1, 1.5, 6, 10]
linelengths1 = [5, 2, 1, 1, 3, 1.5]
plt.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    linelengths=linelengths1)
plt.show()

# %%
f = plt.figure()
plt.scatter(0,0)
nx = int(f.get_figwidth() * f.dpi)
ny = int(f.get_figheight() * f.dpi)
data = np.random.random((ny, nx))
f.figimage(data)
plt.show()

# %%
plt.scatter(x,y,label="dfghj")
plt.figlegend()
#plt.figtext(x,y,[f"dfgh{i}" for i in range(len(x))])
plt.figtext(0,0,"dfgh")
plt.show()

# %%
plt.fill(x,y,color="g",alpha=0.5)
plt.plot(x,y,"-or",mfc="w",mec="b",mew=2)

# %%
plt.hexbin(x,y,gridsize=10)
plt.show()

# %%
x = x_backup.copy()
plt.hist(x)
plt.show()

# %%
x = x_backup.copy()
y = y_backup.copy()
plt.hist2d(x,y)
plt.colorbar()
plt.show()

# %%
plt.hlines(y,1,3)
plt.show()

# %%
data = plt.imread("Moment diagram.png")
plt.imshow(data)
plt.imsave("yo.png",data)
plt.show()

# %%
display((plt.locator_params))
# Out:
# <function matplotlib.pyplot.locator_params(axis='both', tight=None, **kwargs)>

# %%
t = np.linspace(0,100)
plt.loglog(t,t)
plt.show()
plt.semilogx(t,t)
plt.show()
plt.semilogy(t,t)
plt.show()
plt.show()

# %%
plt.magnitude_spectrum(x)
plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 6]
labels = ['Frogs', 'Hogs', 'Bogs', 'Slogs']

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
#plt.margins(0.2)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()

plt.plot(x, y)
# You can specify a rotation for the tick labels in degrees or with keywords.
plt.xticks(x, labels, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)
plt.show()

# %%
plt.matshow((x,y))
#plt.colorbar()

# %%
dx, dy = 0.015, 0.05
y, x = np.mgrid[slice(-4, 4 + dy, dy),
                slice(-4, 4 + dx, dx)]
z = (1 - x / 3. + x ** 6 + y ** 3) * np.exp(-x ** 2 - y ** 2)
z = z[:-1, :-1]
z_min, z_max = -np.abs(z).max(), np.abs(z).max()
     
c = plt.pcolormesh(x, y, z, cmap ='Greens', vmin = z_min, vmax = z_max)
plt.colorbar(c)
  
plt.title('matplotlib.pyplot.pcolormesh() function Example', fontweight ="bold")
plt.show()

# %%
x = x_backup.copy()
plt.phase_spectrum(x)
plt.show()

# %%
plt.pie(x[::10])
plt.show()

# %%
x = x_backup.copy()
y = y_backup.copy()
plt.plot(x,y,"-or",ms=5,mfc="w",mec="b",mew=2)
plt.show()
plt.plot_date(x,y)
plt.show()

# %%
plt.polar(x,y,"-or",ms=5,mfc="w",mec="b",mew=2)
plt.show()

# %%
plt.stackplot(x,y)

# %%
plt.stem(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.suptitle("oiuztr")
plt.show()

# %%
plt.scatter(0,0)
plt.table([x,y])
plt.show()

# %%
plt.vlines(x,y,3)
plt.show()

# %%
plt.scatter(x,y)
plt.yscale("logit")

# %%
x = np.linspace(-np.pi, np.pi, 100)
y = 2 * np.sin(x)

rc = {"xtick.direction" : "inout", "ytick.direction" : "inout",
      "xtick.major.size" : 5, "ytick.major.size" : 5,}
with plt.rc_context(rc):
    fig, ax = plt.subplots()
    ax.plot(x, y)

    ax.spines['left'].set_position('zero')
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_position('zero')
    ax.spines['top'].set_visible(False)

    # make arrows
    ax.plot((1), (0), ls="", marker=">", ms=10, color="k",
            transform=ax.get_yaxis_transform(), clip_on=False)
    ax.plot((0), (1), ls="", marker="^", ms=10, color="k",
            transform=ax.get_xaxis_transform(), clip_on=False)

    plt.show()

# %%
help(plt.box)
plt.rcParams
# Out:
# Help on function box in module matplotlib.pyplot:
#
# box(on=None)
#     Turn the axes box on or off on the current axes.
#
#     Parameters
#     ----------
#     on : bool or None
#         The new `~matplotlib.axes.Axes` box state. If ``None``, toggle
#         the state.
#
#     See Also
#     --------
#     :meth:`matplotlib.axes.Axes.set_frame_on`
#     :meth:`matplotlib.axes.Axes.get_frame_on`
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
# ...

# %%
#P
